# %%
#REPEATITION OPERATOR:
l=[0,1]*3
print(l)
# Out:
# [0, 1, 0, 1, 0, 1]

# %%
#XOR OPERATOR(^):
a=5
b=6
print(a^b)
# Out:
# 3

# %% [markdown]
# **PACKAGES**
#
# Two methods:
#
# 1.from source import func
#
#    func(args)
#
# 2.import source
#
#    source.func(args)

# %% [markdown]
# **oops**
#
# 1.class
#
# 2.methods-functions defined in a class
#
# 3.objects-created to access classes
#
# 4.seld-the first arg passed to methods to indicate that they belong to the present class

# %%
class A:
  def name(self,x):
    print("Name is",x)
obj=A()
myname='abc'
obj.name(myname)
# Out:
# Name is abc

# %% [markdown]
# **CONSTRUCTOR**
#
# It is the first method in class
#
# It stores the variables present in the class
#
# There are 2 types of constructors
#
# 1.default constructor
#
#     It doesnot has any arguments
# 2.parameterized constructor
#
#     It contains arguments

# %%
class const:
  def __init__(self):
    pass
print('PROGRAMMING')
# Out:
# PROGRAMMING

# %%
class Stu:
  student_name='No name'
  def __init__(self,name):
    self.sname=name
    print('Class variable:',self.student_name)
a1=input()
s1=Stu(a1)
print('Passed variable:',s1.sname)
# Out:
# xyz
# Class variable: No name
# Passed variable: xyz

# %%
#student class
#variables - name,roll number,branch,marks,attendence
#methods - view_attendence(),view_marks(),view_name(),update_name()
class Student:
  #parameterized constructor
  def __init__(self,name,marks,attendence):
    self.name=name
    self.marks=marks
    self.attendence=attendence
  def view_name(self):
    print('Student name is:',name)
  def update_name(self,new_name):
    self.name=new_name
    print('Student new name:',self.name)
  def view_marks(self):
    print('Student marks:',self.marks)
  def attendance(self):
    print('Student attendance:',self.attendence)
name=input('Enter name:')
marks=int(input('Enter marks:'))
attendence=int(input('Enter attendence:'))
obj=Student(name,marks,attendence)
obj.view_name()
# Out:
# Enter name:abc
# Enter marks:98
# Enter attendence:95
# Student name is: abc

# %%
#count no of pairs in the given list whose sum is equal to given sum
l=list(map(int,input().split()))
k=int(input())
d=[]
for i in range(len(l)):
  a=k-l[i]
  l1=l[i+1:]
  if a in l1 and [l[i],a] not in d:
    d.append([l[i],a])
print(d)
print(len(d))
# Out:
# 1 4 7 5 6 4 3 5
# 10
# [[4, 6], [7, 3], [5, 5], [6, 4]]
# 4

# %%
#bank details
class bank:
  def __init__(self,username,account_no,branch):
    self.username=username
    self.account_no=account_no
    self.branch=branch
  def print_details(self):
    print('Username:',self.username)
    print('Account_no:',self.account_no)
    print('Branch:',self.branch)
name=input()
account_no=int(input())
branch=input()
obj=bank(name,account_no,branch)
obj.print_details()
# Out:
# abc
# 5672348901
# xyz
# Username: abc
# Account_no: 5672348901
# Branch: xyz
